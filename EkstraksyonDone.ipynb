# %%
# %matplotlib inline
import pandas

# %%
frame = pandas.read_json("/Users/tipanverella/Documents/DATA/kiva/loans.json")

# %%
frame['partner_id'] = frame['partner_id'].astype(str)
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2176690 entries, 0 to 2176689
# Data columns (total 32 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   id                               int64
#  1   name                             object
#  2   original_language                object
#  3   original_description             object
#  4   translated_description           object
#  5   funded_amount                    int64
#  6   loan_amount                      int64
#  7   status                           object
#  8   image_id                         object
#  9   video_id                         object
#  10  activity                         object
#  11  sector                           object
#  12  use                              object
#  13  country_code                     object
#  14  country_name                     object
#  15  town                             object
# ...

# %%
sorted(frame.country_name.unique())
# Out:
# ['Afghanistan',
#  'Albania',
#  'Armenia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa Rica',
#  "Cote D'Ivoire",
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Fiji',
#  'Gaza',
#  'Georgia',
#  'Ghana',
#  'Guam',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'India',
#  'Indonesia',
#  'Iraq',
#  'Israel',
#  'Jordan',
#  'Kenya',
#  'Kosovo',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic",
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Mozambique',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Nicaragua',
#  'Nigeria',
#  'Pakistan',
#  'Palestine',
#  'Panama',
#  'Papua New Guinea',
# ...

# %%
frame.query("country_name == 'Haiti'").sample(5)
# Out:
#               id           name original_language  \
# 323137   1121003          Vanel            French
# 626768    871459          Rolin            French
# 629986   1633693       Precilia            French
# 460898   1747698       Loulouse            French
# 1879912  1682990  Fils Acelomme            French
#
#                                       original_description  \
# 323137   Vanel a 37 ans, il est marié et il a quatre en...
# 626768   Rollin a 44 ans. Il est célibataire et n'a pas...
# 629986   Precilia a utilisé son prêt précédent pour aug...
# 460898   Loulouse progresse considérablement, avec le p...
# 1879912  Fils Acelomme gère avec efficacité son épiceri...
#
#                                     translated_description  funded_amount  \
# 323137   Vanel is 37 years old, married, and has four c...            325
# 626768   Rolin is 44 years old. He is single and has no...            425
# 629986   Precilia had used her previous loan to increas...            225
# ...

# %%
frame.query("country_name == 'Haiti'").index.size
# Out:
# 8595

# %%
12/7000, frame.query("country_name == 'Haiti'").index.size / frame.index.size
# Out:
# (0.0017142857142857142, 0.003948655986842408)

# %%
frame.query("country_name == 'Haiti'").to_parquet("Ayiti.parq")
