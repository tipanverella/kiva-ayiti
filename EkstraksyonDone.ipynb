# %%
# %matplotlib inline
import pandas

# %%
unibank = pandas.read_excel("/home/tipanverella/sdCard/Downloads/data__.xlsx", header=1)

# %%
unibank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15784 entries, 0 to 15783
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Genre                         15784 non-null  object
#  1   Date de Naissance             15784 non-null  object
#  2   Status Conjugal               14633 non-null  object
#  3   Departement                   15663 non-null  object
#  4   Ville                         15663 non-null  object
#  5   Quartier                      0 non-null      float64
#  6   Salarie                       0 non-null      float64
#  7   Secteur                       14096 non-null  object
#  8   Salaire (mensuel en gourdes)  0 non-null      float64
#  9   Departement.1                 0 non-null      float64
#  10  Ville.1                       0 non-null      float64
#  11  Zone                          0 non-null      float64
#  12  Niveau d'Education            13940 non-null  object
#  13  But du Pret                   0 non-null      float64
#  14  Montant du Pret (en gourdes)  15784 non-null  int64
#  15  Duree du Pret (en mois)       15784 non-null  int64
#  16  Date du Contract              15784 non-null  object
#  17  Taux d'Interet (mensuel)      15784 non-null  float64
#  18  Colaterale                    0 non-null      float64
#  19  Valeur Estime du Colaterale   0 non-null      float64
#  20  Status                        0 non-null      float64
#  21  payment restant (en mois)     15784 non-null  float64
#  22  payment manque (en mois)      15784 non-null  int64
# dtypes: float64(12), int64(3), object(8)
# memory usage: 2.8+ MB

# %%
unibank.to_parquet("unibank.parq")

# %%
frame = pandas.read_json("/Users/tipanverella/Documents/DATA/kiva/loans.json")

# %%
frame['partner_id'] = frame['partner_id'].astype(str)
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2176690 entries, 0 to 2176689
# Data columns (total 32 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   id                               int64
#  1   name                             object
#  2   original_language                object
#  3   original_description             object
#  4   translated_description           object
#  5   funded_amount                    int64
#  6   loan_amount                      int64
#  7   status                           object
#  8   image_id                         object
#  9   video_id                         object
#  10  activity                         object
#  11  sector                           object
#  12  use                              object
#  13  country_code                     object
#  14  country_name                     object
#  15  town                             object
#  16  currency_policy                  object
#  17  currency_exchange_coverage_rate  float64
#  18  currency                         object
#  19  partner_id                       object
#  20  posted_time                      datetime64[ns, UTC]
#  21  planned_expiration_time          datetime64[ns, UTC]
#  22  disbursed_time                   datetime64[ns, UTC]
#  23  funded_time                      datetime64[ns, UTC]
#  24  term_in_months                   int64
#  25  lender_count                     int64
#  26  journal_entries_count            int64
#  27  bulk_journal_entries_count       int64
#  28  tags                             object
#  29  repayment_interval               object
#  30  distribution_model               object
#  31  borrowers                        object
# dtypes: datetime64[ns, UTC](4), float64(1), int64(7), object(20)
# memory usage: 531.4+ MB

# %%
sorted(frame.country_name.unique())
# Out:
# ['Afghanistan',
#  'Albania',
#  'Armenia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa Rica',
#  "Cote D'Ivoire",
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Fiji',
#  'Gaza',
#  'Georgia',
#  'Ghana',
#  'Guam',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'India',
#  'Indonesia',
#  'Iraq',
#  'Israel',
#  'Jordan',
#  'Kenya',
#  'Kosovo',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic",
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Mozambique',
#  'Myanmar (Burma)',
#  'Namibia',
#  'Nepal',
#  'Nicaragua',
#  'Nigeria',
#  'Pakistan',
#  'Palestine',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Puerto Rico',
#  'Rwanda',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'Senegal',
#  'Sierra Leone',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Sri Lanka',
#  'Suriname',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'The Democratic Republic of the Congo',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United States',
#  'Uruguay',
#  'Vanuatu',
#  'Vietnam',
#  'Virgin Islands',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
frame.query("country_name == 'Haiti'").sample(5)
# Out:
#               id          name original_language  \
# 283812   1591587      Marimene            French
# 810645   1477114      Islande             French
# 156664   2094285     Marilaine            French
# 1711797   760462      Keteline           English
# 2059890  2077646  Jeanne Marie            French
#
#                                       original_description  \
# 283812   Marimene travaille très dur pour tenir en vie ...
# 810645   Islande  est âgée de 31 ans. Elle vit avec ses...
# 156664   Marilaine vend des sous-vêtements pour répondr...
# 1711797  Keteline is a 27-year-old mother of three chil...
# 2059890  Jeanne Marie a beaucoup progressé, elle a util...
#
#                                     translated_description  funded_amount  \
# 283812   Marimene works hard to keep her business runni...            350
# 810645   Islande is 31 years old. She lives with her pa...            625
# 156664   Marilaine sells undergarments to support her f...            425
# 1711797  Keteline is a 27-year-old mother of three chil...            325
# 2059890  Jeanne Marie has made a lot of progress.  She ...            450
#
#          loan_amount  status image_id video_id  ...            disbursed_time  \
# 283812           350  funded  2928615           ... 2018-07-31 07:00:00+00:00
# 810645           625  funded  2781062           ... 2018-02-09 08:00:00+00:00
# 156664           425  funded  4172159           ... 2020-12-23 08:00:00+00:00
# 1711797          325  funded  1680749           ... 2014-09-02 07:00:00+00:00
# 2059890          450  funded  4136815           ... 2020-11-30 08:00:00+00:00
#
#                       funded_time term_in_months lender_count  \
# 283812  2018-08-26 16:43:04+00:00              8            7
# 810645  2018-02-26 19:32:47+00:00              8           22
# 156664  2021-01-24 19:36:28+00:00             10           16
# 1711797 2014-09-25 00:48:03+00:00             75           11
# 2059890 2020-12-21 20:48:50+00:00              8           18
#
#         journal_entries_count bulk_journal_entries_count  \
# 283812                      1                          1
# 810645                      1                          1
# 156664                      1                          1
# 1711797                    19                         11
# 2059890                     1                          1
#
#                                                     tags  repayment_interval  \
# 283812         [#Woman-Owned Business, #Repeat Borrower]             monthly
# 810645                                                []             monthly
# 156664   [#Eco-friendly, #Parent, #Woman-Owned Business]             monthly
# 1711797                                               []           irregular
# 2059890                                 [volunteer_pick]             monthly
#
#         distribution_model                                          borrowers
# 283812       field_partner  [{'name': 'Marimene', 'gender': 'female', 'is_...
# 810645       field_partner  [{'name': 'Islande ', 'gender': 'female', 'is_...
# 156664       field_partner  [{'name': 'Marilaine', 'gender': 'female', 'is...
# 1711797      field_partner  [{'name': 'Keteline', 'gender': 'female', 'is_...
# 2059890      field_partner  [{'name': 'Jeanne Marie', 'gender': 'female', ...
#
# [5 rows x 32 columns]

# %%
frame.query("country_name == 'Haiti'").index.size
# Out:
# 8595

# %%
12/7000, frame.query("country_name == 'Haiti'").index.size / frame.index.size
# Out:
# (0.0017142857142857142, 0.003948655986842408)

# %%
frame.query("country_name == 'Haiti'").set_index('id').to_parquet("Ayiti.parq")
