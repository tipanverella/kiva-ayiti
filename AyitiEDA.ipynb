# %%
# %matplotlib inline

# %%
import pandas

# %%
frame = pandas.read_parquet("~/Documents/DATA/kiva/Ayiti.parq")
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8595 entries, 921 to 2176245
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               8595 non-null   int64
#  1   name                             8595 non-null   object
#  2   original_language                8595 non-null   object
#  3   original_description             8595 non-null   object
#  4   translated_description           8595 non-null   object
#  5   funded_amount                    8595 non-null   int64
#  6   loan_amount                      8595 non-null   int64
#  7   status                           8595 non-null   object
#  8   image_id                         8595 non-null   object
#  9   video_id                         8595 non-null   object
#  10  activity                         8595 non-null   object
#  11  sector                           8595 non-null   object
# ...

# %%
df = frame[["id", "funded_amount", "loan_amount", "status", "activity", "sector", "use", "town", "partner_id", "posted_time", "lender_count", "repayment_interval", "distribution_model", "borrowers", "currency"]].set_index("id")
df['partner_id'] = df['partner_id'].astype(str)

# %%
df.groupby("currency").describe().T
# Out:
# currency                      HTG            USD
# funded_amount count   8159.000000     436.000000
#               mean     703.036524    2986.697248
#               std      913.318945   10515.947150
#               min        0.000000       0.000000
#               25%      250.000000     800.000000
#               50%      400.000000    1200.000000
#               75%      750.000000    1500.000000
#               max    12250.000000  100000.000000
# loan_amount   count   8159.000000     436.000000
#               mean     721.807207    3176.032110
#               std      980.101615   10764.600167
#               min       25.000000     100.000000
#               25%      250.000000     850.000000
#               50%      425.000000    1300.000000
#               75%      750.000000    1625.000000
#               max    14875.000000  100000.000000
# lender_count  count   8159.000000     436.000000
#               mean      22.956490      93.128440
# ...

# %%
df.groupby(["currency","sector"]).mean().T
# Out:
# currency              HTG                                                     \
# sector        Agriculture         Arts    Clothing Construction    Education
# funded_amount  737.621359  1559.693878  640.956704  1125.462963  2658.333333
# loan_amount    772.233010  1559.693878  651.396648  1204.629630  2658.333333
# lender_count    23.638835    50.000000   20.851955    35.580247    93.666667
#
# currency                                                                      \
# sector        Entertainment        Food    Health Manufacturing Personal Use
# funded_amount        3725.0  612.255607  981.5625   1760.000000   312.726098
# loan_amount          3725.0  628.299310  981.5625   2024.285714   312.726098
# lender_count          125.0   20.080219   31.4250     57.714286    11.007752
#
# currency       ...          USD                                               \
# sector         ... Construction Education         Food  Health Manufacturing
# ...

# %%
df.groupby(["currency","town"]).mean()
# Out:
#                                 funded_amount   loan_amount  lender_count  \
# currency town
# HTG      Aquin                    2568.750000   2568.750000     86.250000
#          Arniquet, sud torbeck    3812.500000   8412.500000    120.000000
#          Cayes                    1106.578947   1106.578947     36.868421
#          Chardonnieres             680.000000    680.000000     24.800000
#          Dame-Marie                760.869565    760.869565     25.500000
#          Grand'Anse. Caracolie     845.945946    860.810811     26.054054
#          Grand-goave               351.470588    351.470588     10.352941
#          Jeremie                   912.931034    931.034483     30.000000
#          Jeremie, Dame-marie       772.169811   1011.792453     25.000000
#          Jeremie, Simon            920.555556    934.444444     28.555556
#          Les Cayes                 356.250000    356.250000     10.250000
# ...

# %%
df.groupby(["currency","town"])[['partner_id']].describe(include='O')
# Out:
#                                partner_id
#                                     count unique  top freq
# currency town
# HTG                                   163      4  442   68
#          Aquin                          4      2  380    3
#          Arniquet, sud torbeck          2      1  380    2
#          Artibonite                    61      1  380   61
#          Bon Repos                    330      1  442  330
# ...                                   ...    ...  ...  ...
# USD      Thomonde                       1      1  380    1
#          Tiburon                        1      1  260    1
#          Torbeck                        3      1  380    3
#          Trou-du-Nord                  26      1   44   26
#          Turgeau                        1      1  380    1
#
# [118 rows x 4 columns]
