# %%
# %matplotlib inline
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %%
import pandas

# %%
frame = pandas.read_parquet("Ayiti.parq")
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8595 entries, 1824819 to 2186686
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   name                             8595 non-null   object
#  1   original_language                8595 non-null   object
#  2   original_description             8595 non-null   object
#  3   translated_description           8595 non-null   object
#  4   funded_amount                    8595 non-null   int64
#  5   loan_amount                      8595 non-null   int64
#  6   status                           8595 non-null   object
#  7   image_id                         8595 non-null   object
#  8   video_id                         8595 non-null   object
#  9   activity                         8595 non-null   object
#  10  sector                           8595 non-null   object
#  11  use                              8595 non-null   object
# ...

# %%
frame.sample(5).T
# Out:
# id                                                 1143302  \
# name
# original_language
# original_description
# translated_description
# funded_amount                                          250
# loan_amount                                            250
# status                                              funded
# image_id
# video_id
# activity                                       Food Market
# sector                                                Food
# use
# country_code                                            HT
# country_name                                         Haiti
# town
# currency_policy                                     shared
# currency_exchange_coverage_rate                        0.1
# currency                                               HTG
# partner_id                                             442
# posted_time                      2016-08-31 19:11:47+00:00
# planned_expiration_time          2016-10-09 00:40:03+00:00
# ...

# %%
frame.describe()
# Out:
#        funded_amount    loan_amount  currency_exchange_coverage_rate  \
# count    8595.000000    8595.000000                      8595.000000
# mean      818.880163     846.303083                         0.098290
# std      2576.906204    2658.426878                         0.019787
# min         0.000000      25.000000                         0.000000
# 25%       275.000000     275.000000                         0.100000
# 50%       425.000000     425.000000                         0.100000
# 75%       775.000000     800.000000                         0.100000
# max    100000.000000  100000.000000                         0.200000
#
#        term_in_months  lender_count  journal_entries_count  \
# count     8595.000000   8595.000000            8595.000000
# mean        12.114136     26.516114               1.952065
# std         14.427243     76.894121               3.539239
# min          2.000000      0.000000               1.000000
# ...

# %%
frame.describe(include='O')
# Out:
#         name original_language original_description translated_description  \
# count   8595              8595                 8595                   8595
# unique  3966                 4                 8402                   8266
# top                     French
# freq     185              6918                  185                    330
#
#         status image_id video_id activity sector  \
# count     8595     8595     8595     8595   8595
# unique       4     6558        2      108     14
# top     funded                     Retail   Food
# freq      8440      185     8594     1052   3523
#
#                                           use country_code country_name  \
# count                                    8595         8595         8595
# unique                                   5293            1            1
# top     to increase her stock of merchandise.           HT        Haiti
# freq                                      366         8595         8595
#
# ...

# %%
frame.head(10)
# Out:
#                      name original_language  \
# id
# 1824819           Maietta            French
# 760477              Nadia           English
# 1186219      Joseph serge            French
# 1633460           Sylfise            French
# 429352   Jezi Konen Group            French
# 1011346     Marie Sulnice            French
# 1989069         Micheline            French
# 1381297           Felicia            French
# 990328    Marie Louisilia            French
# 1680950          Cherline            French
#
#                                       original_description  \
# id
# 1824819  Marietta est fiere de ses ventes, avec son der...
# 760477   This loan helps Nadia get connected to her loc...
# 1186219  Serge a 53 ans. Il est divorcé et père d’un en...
# 1633460  Sylfise est âgée de 41 ans, vit avec son compa...
# 429352   Marieclaude est la coordonatrice de son groupe...
# 1011346  Sulnice est âgée 59 ans et mère de huit enfant...
# ...
